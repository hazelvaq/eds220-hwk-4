# %% [markdown]
# # Task 2 - Landsat 8 false color image
#
# ## General instructions
#
# First, update the following cell to have a link to your Homework 4 GitHub repository
#
# **UPDATE THIS LINK** https://github.com/hazelvaq/eds220-hwk-4.git
#
# Add comments for all your code and commit as needed. Err on the side of commenting and commiting too much for now.
#
# ## Overview
# The goal of this task is to create a false color image showing the fire scar of the Thomas fire in 2017.
# Read more about false color images here:
# [NASA Earth Observatory - Why is that Forest Red and that Cloud Blue?
# How to Interpret a False-Color Satellite Image](https://earthobservatory.nasa.gov/features/FalseColor)
#
# ## About the data
#
# In this task you will use two datsets:
#
# **First dataset**
#
# A simplified collection of bands (red, green, blue, near-infrared and shortwave infrared) from the Landsat Collection 2 Level-2 atmosperically corrected surface reflectance data, collected by the Landsat 8 satellite.
#
# Information about Landsat bands from USGS:
#
# - [What are the band designations for the Landsat satellites?](https://www.usgs.gov/faqs/what-are-band-designations-landsat-satellites)
#
# -[Common Landsat Band Combinations](https://www.usgs.gov/media/images/common-landsat-band-combinations)
#
# -[How do I use a scale factor with Landsat Level-2 science products?](https://www.usgs.gov/faqs/how-do-i-use-a-scale-factor-landsat-level-2-science-products)
#
#
# The data was accessed and pre-processed in the Microsoft Planetary Computer to remove data outside land and coarsen the spatial resolution ([Landsat Collection in MPC](https://planetarycomputer.microsoft.com/dataset/landsat-c2-l2)). Data should be used for visualization purposes only.
#
#
# **Second dataset**
#
# A shapefile of fire perimeters in California during 2017.
# The [complete file can be accessed in the CA state geoportal](https://gis.data.ca.gov/datasets/CALFIRE-Forestry::california-fire-perimeters-all-1/about).
#
# ## File management
# All your data files must be  inside a directory named 'data' **in your gitignore**.
#
# ## Data access
# All data is in the Canvas-week7-homework zip file.

# %% [markdown]
# ## FINAL CODE
#
# You will use the next cell at the end of the task. Leave it blank for now.

# %%
### ===== FINAL CODE =====
#--------------------Libraries------------------------------------------------------------------------
# import libraries and functions here
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches 

## for geospatial
import xarray as xr
import rioxarray as rioxr
import geopandas as gpd

#--------------------Import Data---------------------------------------------------------------------
# Import California wildfire data
wildfires = gpd.read_file('data/California_Fire_Perimeters_2017/California_Fire_Perimeters_2017.shp')

# Import Landsat
landsat = rioxr.open_rasterio(os.path.join(os.getcwd(),'data','landsat8-2018-01-26-sb-simplified.nc'))

#--------------------Landsat Updates------------------------------------------------------------------
# Our landsat data has 3 dimensions, so we remove the 'band' dimension
# remove length 1 dimension (band)
landsat = landsat.squeeze()
# remove coordinates associated to band
landsat = landsat.drop('band')
#--------------------Wildfire Updates-----------------------------------------------------------------
# Update wildfire CRS to match Landsat CRS
wildfires = wildfires.to_crs(landsat.rio.crs)
# Filter dataset to THOMAS FIRE
wildfires = wildfires[wildfires.FIRE_NAME == 'THOMAS']
#
# Plot Wildfire and Landsat data together
fig, ax = plt.subplots()

# -------------------Landsat Map-----------------------------------------------------------------------
landsat[['swir22','nir08','red']].to_array().plot.imshow(ax=ax,robust = True)
ax.set_facecolor('white')

#--------------------Thomas Fire Layer-----------------------------------------------------------------
wildfires.plot(ax=ax, color = 'none', edgecolor = "yellow", linewidth = 1)
wildfires_patch = mpatches.Patch(color = 'yellow',
                                label = 'Thomas fire perimeter')

# -------------------Legend----------------------------------------------------------------------------
plt.title("Fire scar of Thomas Fire, 2017") # title
ax.legend(handles = [wildfires_patch], frameon = False, loc = "upper right", labelcolor = "white")

plt.show()

# %% [markdown]
# ## Import libraries and functions

# %%
# import libraries and functions here
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches 

## for geospatial
import xarray as xr
import rioxarray as rioxr
import geopandas as gpd

# %% [markdown]
# ## Import data

# %%
# Import California wildfire data
wildfires = gpd.read_file('data/California_Fire_Perimeters_2017/California_Fire_Perimeters_2017.shp')

# Import Landsat
landsat = rioxr.open_rasterio(os.path.join(os.getcwd(),'data','landsat8-2018-01-26-sb-simplified.nc'))

# %% [markdown]
# ## Exploration
#
# Use the next cell(s) to perform relevant explorations of these datasets.

# %%
# Explore wildfires dataset
# wildfires CRS
print(f"Wildfire CRS:{wildfires.crs}")

# View dataframe
wildfires.head(3)
# Out:
# Wildfire CRS:epsg:3857
#    index  OBJECTID YEAR_ STATE AGENCY UNIT_ID FIRE_NAME   INC_NUM  ALARM_DATE  \
# 0  19836     41429  2017    CA    CCO     VNC     BROOK  00042450  2017-05-23
# 1  19837     41430  2017    CA    CCO     VNC   PACIFIC  00075307  2017-09-09
# 2  19838     41431  2017    CA    CCO     VNC     GRADE  00054660  2017-07-04
#
#     CONT_DATE  ...  GIS_ACRES  \
# 0  2017-05-24  ...  10.043819
# 1  2017-09-09  ...   1.190109
# 2  2017-07-05  ...  47.194027
#
#                                             COMMENTS  COMPLEX_NA  COMPLEX_IN  \
# 0                                   per walked track        None        None
# 1  Final Walked track.  Small spot to the north east        None        None
# 2                                               None        None        None
#
#   IRWINID FIRE_NUM DECADES   SHAPE_Leng     SHAPE_Area  \
# 0    None     None    2010  1246.055781   59473.666651
# 1    None     None    2010   561.418202    7081.369481
# 2    None     None    2010  2587.259697  279911.825212
#
#                                             geometry
# 0  POLYGON ((-13229812.974 4046876.486, -13229786...
# 1  POLYGON ((-13286872.985 4074523.355, -13286895...
# 2  POLYGON ((-13244637.580 4056332.530, -13244620...
#
# [3 rows x 23 columns]

# %%
# Plot wildfire 
wildfires.plot()
# Out:
# <AxesSubplot:>

# %%
# Explore landsat data
print(f"Landsat CRS: {landsat.rio.crs}")
landsat
# Out:
# Landsat CRS: EPSG:32611
# <xarray.Dataset>
# Dimensions:      (y: 731, x: 870, band: 1)
# Coordinates:
#   * y            (y) float64 3.952e+06 3.952e+06 ... 3.756e+06 3.755e+06
#   * x            (x) float64 1.213e+05 1.216e+05 ... 3.557e+05 3.559e+05
#   * band         (band) int64 1
#     spatial_ref  int64 0
# Data variables:
#     red          (band, y, x) float64 ...
#     green        (band, y, x) float64 ...
#     blue         (band, y, x) float64 ...
#     nir08        (band, y, x) float64 ...
#     swir22       (band, y, x) float64 ...

# %% [markdown]
# ## Updates
#
# If there are any updates needed to the data to plot the true and false color images, perform them in the next cells (you may add as many as you need).
# Comment appropriately.

# %%
# There are 3 dimensions in Landsat let's drop band
# original dimensions and coordinates
print(f"Original dimensions: {landsat.dims} \n{landsat.coords}")

# remove length 1 dimension (band)
landsat = landsat.squeeze()
print(landsat.dims, landsat.coords, '\n')

# remove coordinates associated to band
landsat = landsat.drop('band')
print(landsat.dims, landsat.coords, '\n')
# Out:
# Original dimensions: Frozen({'y': 731, 'x': 870, 'band': 1})
# Coordinates:
#   * y            (y) float64 3.952e+06 3.952e+06 ... 3.756e+06 3.755e+06
#   * x            (x) float64 1.213e+05 1.216e+05 ... 3.557e+05 3.559e+05
#   * band         (band) int64 1
#     spatial_ref  int64 0
# Frozen({'y': 731, 'x': 870}) Coordinates:
#   * y            (y) float64 3.952e+06 3.952e+06 ... 3.756e+06 3.755e+06
#   * x            (x) float64 1.213e+05 1.216e+05 ... 3.557e+05 3.559e+05
#     band         int64 1
#     spatial_ref  int64 0
#
# Frozen({'y': 731, 'x': 870}) Coordinates:
#   * y            (y) float64 3.952e+06 3.952e+06 ... 3.756e+06 3.755e+06
#   * x            (x) float64 1.213e+05 1.216e+05 ... 3.557e+05 3.559e+05
#     spatial_ref  int64 0

# %% [markdown]
# ## True color image
#
# Without creating any new variables:
#
# Select the red, green and blue variables (in that order) of the `xarray.Dataset`, convert it to a `numpy.array` using the `to_array()` method, and then use `.plot.imshow()` to create an RGB image with the data. (There will be a warning)

# %%
# Create an RGB image with the data
landsat[['red','green','blue']].to_array().plot.imshow()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Adjust the scale used for plotting the bands to get a true color image.
# HINT: [Check the `robust` parameter](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imshow.html)
# The issue here is the clouds: their RGB values are outliers and cause the other values to be squished when plotting.

# %%
# Adjust the scale uesd for plotting
landsat[['red','green','blue']].to_array().plot.imshow(robust = True)

# %% [markdown]
# ## False color image
# Without creating any new variables:
#
# Create a false color image by plotting the short-wave infrared (swir22), near-infrared, and red variables (in that order).

# %%
# False color image
landsat[['swir22','nir08','red']].to_array().plot.imshow(robust = True)

# %% [markdown]
# ## Updates
#
# If there are any updates needed to the data to create the map, perform them in the next cells (you may add as many as you need).
# Comment appropriately.

# %%
# Update wildfire CRS to match Landsar CRS
wildfires = wildfires.to_crs(landsat.rio.crs)

# Check update
wildfires.crs

# Plot Wildfire and Landsat data together
fig, ax = plt.subplots()

landsat[['swir22','nir08','red']].to_array().plot.imshow(ax=ax,robust = True)

wildfires.plot(ax=ax)
plt.show() # We need to clip Wildfires data to just be in Landsat boundaries

# %%
# View Wildfires dataset
print(wildfires.FIRE_NAME.unique()) # We are interested in the THOMAS FIRE

# Filter dataset to THOMAS FIRE
wildfires = wildfires[wildfires.FIRE_NAME == 'THOMAS']

# View map of newly filtered data
wildfires.plot()
# Out:
# ['BROOK' 'PACIFIC' 'GRADE' 'PACIFICA' 'MONTVIEW' 'PALMA' 'CANYON' 'VISTA'
#  'BALDWIN' 'ROLLING' 'MCWANE' 'SCHOOL\r\nSCHOOL' 'FORK' 'LIBBEY' 'SCALES'
#  'RUNNER' 'DINELY' 'ROADRUNNER' 'ELEPHANT 2' 'TEHAMA' 'BOLLA' 'CRABTREE'
#  'FALLS' 'GOLD' 'HARNEY' 'JACKSONVILLE' 'LAKE' 'MARIA' 'MILTON' 'ORANGE'
#  'PALOMA' 'QUAIL' 'RED' 'TABLE' 'TWIST' 'WILLMS' 'ZAMORA' 'POINT' 'ROCKY'
#  'SHANDON' 'SOLAR' 'LUCY' 'TOWER' 'OLIVE' 'CYPRESS' 'CHALK' 'STONE' 'WEST'
#  'ALAMO' 'HILL' 'GAVIOTA' 'ZENON' 'CAMATTA' 'RANCH' 'MARGARITA' 'HUASNA'
#  'COVE' 'POLY' 'LINNE' 'SODA' 'LYNCH' 'CAMP' 'VILLA' 'CRAM' 'HILT'
#  'CANTERA' 'EDGEWOOD' 'WHITEPINE' 'KILLGORE' 'OAKWOOD' 'DAVIS' 'BOGUS'
#  'HORNBROOK' 'MACDOEL' 'APSUUN' 'BAILEY' 'DORRIS' 'COMSTOCK' 'FAY'
#  'SHULMEYER' 'HAWKINSVILLE' 'MEADOW' 'GAZELLE' 'STATELINE' 'PLEASANT'
#  'OWENS' 'JUNIPER' 'MARBLE' 'DEER ONE' 'RAILROAD' 'MILL' 'SHELL' 'BARR'
#  'JADE' 'MODOC' 'LAVERNE' 'GRACE' 'CORNER' 'BERRY' 'CORAL' 'BALLY'
#  'FELIPE' 'LARIAT' 'AIR' 'BELL' 'CEBRIAM' 'TRAIL' 'RUCKER' 'WOODCHOPPER 2'
#  'ARMOUR' 'VINEYARD' 'WESTERLY' 'CAT' 'HWY_1' 'DRUM' 'MESA' 'LAMB'
#  'LAMB 2' 'OPERA' 'ROSE' 'VERNON' 'PALMER' 'MIAS' 'BLAINE' 'EXTENSION'
#  'SMILEY' None 'IRVINE PARK' 'ANTONIO' 'TESORO SCHOOL' 'MAGAZINE' 'NIGUEL'
#  'LAGUNA NIGUEL REGIONAL PARK' 'GEORGIA SUE' 'TRAFALGAR CANYON' 'JEFFREY'
#  'CROSS CREEK' 'CANYON I' 'CANYON II' 'LAMBERT' 'CREEK' 'TOMATO SPRINGS'
#  'CARBON CANYON PARK' 'WOOD' 'JASPER' 'GREENHORN' 'CHINA' 'STAGECOACH'
#  'REX' 'GRIZZLY' 'CATLETT' 'MAVERICK' 'BROPHY' 'SMARTSVILLE' 'BLACKFORD'
#  'BEALE' 'SPENCEVILLE' 'MCCOURTNEY' 'GARDEN' 'LOBO' 'BREWER' 'BORDER 9'
#  'SLOANE' 'WILSON' 'SUNSHINE COMPLEX' 'MONTEZUMA' 'LILAC' 'JENNINGS 2'
#  'GREENFIELD' 'GATE' 'ECLIPSE' 'DEHESA 5' 'BORDER 6' 'BLACK' 'BANDY 2'
#  'PEAK' 'MISSION' 'DETWILER' 'BEN' 'WRIGHT' 'SPRING' 'CORONADO' 'SMITH'
#  'BEAR' 'KNOXVILLE' 'GEYSERS' 'MURPHY' 'SITES' 'TOLL' 'SANDS' 'BOTTLE'
#  'FOOTHILL' 'INDEPENDENCE' 'LAKEVILLE' 'TIMM' 'WINTER' 'BODEGA' 'ESTATE'
#  'FORT' 'REDWOOD' 'MULE' 'SPRINGS' 'RIDGE' 'NUNS' 'PRESSLEY' 'YOUNG'
#  'TUBBS' 'POCKET' 'ATLAS' 'SULPHER' 'CLOVER' 'ROCKVILLE' 'CENTERVILLE'
#  'PINE' 'JOESPH' '3-20' 'ENCINAL' 'PLACERITA' 'STOKES' 'GAVINA'
#  'MULHOLLAND' 'BARN' 'FIVE' 'SOUTH' 'WAGON' 'BROWNS' 'PALMS' 'JOHNSON'
#  'NEENACH' 'OLD' 'HASLEY' 'MARTINEZ' 'COYOTE' 'MEDLEY' 'TETON' 'LEONA'
#  'ESCONDIDO' 'PARKMOR' 'TOWSLEY' 'RODEO' 'GORMAN' 'SIERRA' 'HACIENDA'
#  'SKYLINE' 'RAMBLA' 'RYE' 'MING' 'HUB' 'CHAMPAGNE' 'HAWK' 'TANK' 'SWITCH'
#  'LAKEWOOD' 'GULTCH' 'CALGARY' 'FARMER' 'RESOURCE' 'HILL CREST' 'LOOP'
#  'AIRPORT' 'MID' 'OILFIELD' 'GRANITE' 'FEED' 'TOWERLINE' 'TEJON' 'DERBY'
#  'ELK' 'ERIC' 'HILLS' 'AQUADUCT' 'CORCARAN' 'OWL' 'BRECKENRIDGE'
#  'CARNATION' 'R-4 PARSNIP' 'W-2 LIKELY' 'ALPAUGH' 'RIVER' 'SHAFFER'
#  'LONG VALLEY' 'R-10 PAINTER' 'R-2 SCHAFFER' 'R-9 SHINN' 'R-4 RANCH'
#  'R-3 MUD' 'R-5 STONEY' 'R-9 FREDONYER' 'PEG' 'CHERRY' 'MUD' 'R-5 SPANISH'
#  'R-2 BUTTE WELL' 'BLUE' 'CAHUILA' 'CHRISTMAS' 'HIGHLINE' 'IRWIN' 'MATZ'
#  'TECOPA' 'WINDMILLS' 'MOTOR' 'KECK' 'W4 ROMERO' 'COWHEAD' 'PANOCHE'
#  'FAIRVIEW' 'PICNIC' 'SLINKARD' 'DRY VALLEY' 'SPALLETTA' 'HOGBACK'
#  'EASTMAM' 'MANZANITA' 'SHAVER' 'MONTEREY' 'PARKFIELD' 'SILVER' 'TUMEY'
#  'GARZA' 'JAYNE' 'PARK' 'FREEDOM' 'TIVY' 'ELM' 'DERRICK' 'COALINGA' 'CITY'
#  'AVENAL' 'AUBERRY' 'FLAT' 'POTATO' 'HELENA' 'CHILCOOT' 'ELEPHANT'
#  'MCCORMICK' 'DOUGLAS' 'BUMMERS' 'WILLOW' 'PILOT' 'GRANT' 'TWIN' 'BURNEY'
#  'DUTCHMAN' 'FORKS' 'FRANK' 'HAYPRESS' 'RIVERS' 'SECRET' 'SWAY' 'UKONOM'
#  'WILLIE' 'ROWELL' 'SCHAEFFER' 'PIER' 'CALDWELL' 'LION' 'HIGHWAY'
#  'NEEDLES' 'CROWN' 'QUARTZ' 'BUTTE' 'COW' 'BRADLEY' 'BRIDGE' 'BUCK'
#  'PICKETT' 'SANDY' 'CHATTER' 'FRENCHMAN' 'POSLIN' 'DIXIE' 'CRESCENT'
#  'SQUIRREL' 'GENESSEE' 'MINERVA 5' 'MILLS' 'EUREKA' 'SLIDE' 'SKELETON'
#  'WHITTIER' 'APACHE' 'POZO' 'THOMAS' 'ANTELOPE' 'CEDAR' 'CLAIRE' 'DEEP'
#  'FOURTH' 'ISLAND' 'LITTLE BUCK' 'MARY' 'OAK' 'WALLOW' 'KLAMATH' 'ICE'
#  'MORMON' 'LONG' 'WINTON' 'MIDDLE' 'HORSE' 'LOST' 'WILDOMAR' 'JARDINE'
#  'CAPTAIN' 'JAMESON' 'HOLCOMB' 'BRIDGE 2' 'DOLLAR' 'HIDDEN' 'MART'
#  'MELVIN' 'MILE' 'ROUSE' 'SEINE' 'OSITA' 'DOMINICA' 'CHARLTON' 'ZERMATT'
#  'RINCON' 'VALLEY' 'ROCK2' 'DOBE' 'RIMROCK' 'RIMROCK2' 'CLARK' 'STEELE'
#  'DIAMOND4' 'JONES' 'BOLES' 'RADAR' 'MOWITZ' 'ROCK' 'JIM' 'BLUE2'
#  'QUAKING' 'CANTRALL' 'BATTLE' 'DIAZ' 'INDIAN' 'PAYNE' 'SKYWAY' 'CHEROKEE'
#  'PONDEROSA' 'WALL' 'HONEY' 'THIRTY TWO' 'BLOCKSBURG' 'SAW' 'MILLER'
#  'SHORE' 'SKEGGS' 'LONEOAK' 'BITTERWATER' 'HOG' 'ALVARADO' 'KING'
#  'SAN JUAN' 'COUNTRY' 'UNION' 'HIGH' 'BRYANT 2' 'CABLE' 'LATROBE' 'FRENCH'
#  'AXEL' 'LARGO' 'STONY' 'TONZI' 'CASCADE' 'POHONO' 'RIBBON'
#  'YOSEMITE CREEK' 'SHORELINE' 'BENSON PASS' 'LECONTE' 'EMPIRE' 'WATKINS'
#  'WOLFE' 'EL CAP' 'COYOTE ROCKS' 'DRAKE 2' 'AVALANCH VEHICLE FIRE'
#  'A RANCH' 'JAY' 'INSPIRATION' 'NORTH GUARD' 'INDIAN CANYON' 'HARDIN'
#  'MORRISON' 'ILLILOUETTE CREEK' 'VISION' 'PORCUPINE CAMPGROUND' 'TUNNEL'
#  'RATTLESNAKE' 'NORTH DOME' 'SENTINEL' 'FORD LAKE' 'KNOB 91' 'MARKET'
#  'PORCUPINE' 'INDIAN ROCK' 'SHALE' 'STARR KING' 'CRANE' 'LA TUNA'
#  'PARKER2' 'SOUTH FORK' 'REDWOOD VALLEY' 'ABNEY' 'KNOX' 'GOODALE' 'FORNI'
#  'CRISTIANITOS' 'TOPANGA' 'SKIRBALL' '37' 'TURKEY TRACT' 'STUBBLE'
#  'HUDSON' 'HARKIN']
# <AxesSubplot:>

# %% [markdown]
# ## Map
# Create a map showing the shortwave infrared/nir/ ed false color image together with the Thomas fire perimeter.
# Customize it appropriately.

# %%
# Plot Wildfire and Landsat data together
fig, ax = plt.subplots()

# ---Landsat Map------------------------------------------------------------------------
landsat[['swir22','nir08','red']].to_array().plot.imshow(ax=ax,robust = True)
ax.set_facecolor('white')

#---Thomas Fire Layer-------------------------------------------------------------------
wildfires.plot(ax=ax, color = 'none', edgecolor = "yellow", linewidth = 1)
wildfires_patch = mpatches.Patch(color = 'yellow',
                                label = 'Thomas fire perimeter')

# ---Legend-----------------------------------------------------------------------------
plt.title("Fire scar of Thomas Fire, 2017") # title
ax.legend(handles = [wildfires_patch], frameon = False, loc = "upper right", labelcolor = "white")

plt.show()

# %% [markdown]
# ## Final code
#
# Collect all the relevant code into the first blank cell of the notebook titled "FINAL CODE". This single cell will have the end-to-end workflow: from importing libraries and loading the data, to producing the graph. The only ouput of this cell should be the plot you produced in the previous exercise.
#
# Add divisions for relevant sections and comment appropriately.
